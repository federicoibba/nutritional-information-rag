# %% [markdown]
# # Dataset notebook
#
# Import all the different chunks of the dataset, put into a single file and remove unneeded columns (first two)

# %%
import pandas as pd

# %%
df = pd.read_csv('openfood_dataset.tsv', sep='\t', low_memory=False)

# %% [markdown]
# ## Extract just the column needed
#
# - product_name
# - fat_100g
# - carbohydrates_100g
# - proteins_100g
# - energy_100g (kJ)
# - saturated_fat_100g
# - sugars_100g
# - fiber_100g
# - salt_100g

# %%
COLUMNS = ["product_name", "fat_100g", "carbohydrates_100g", "proteins_100g", "energy_100g", "saturated-fat_100g", "sugars_100g", "fiber_100g", "salt_100g"]

# %%
df_projected = df[COLUMNS]
df_projected.columns = ['product name', 'fat', 'carbohydrates', 'proteins', 'calories', 'saturated fat', 'sugars', 'fiber', 'salt']

# %%
df_projected
# Out:
#                                              product name    fat  \
# 0                                      Farine de blé noir    NaN
# 1                          Banana Chips Sweetened (Whole)  28.57
# 2                                                 Peanuts  17.86
# 3                                  Organic Salted Nut Mix  57.14
# 4                                         Organic Polenta   1.43
# ...                                                   ...    ...
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...   0.00
# 356023                                            乐吧泡菜味薯片    NaN
# 356024                                      Biscottes bio    NaN
# 356025                           Tomates aux Vermicelles     NaN
# 356026                    Sugar Free Drink Mix, Peach Tea   0.00
#
#         carbohydrates  proteins  calories  saturated fat  sugars  fiber  \
# 0                 NaN       NaN       NaN            NaN     NaN    NaN
# 1               64.29      3.57    2243.0          28.57   14.29    3.6
# 2               60.71     17.86    1941.0           0.00   17.86    7.1
# 3               17.86     17.86    2540.0           5.36    3.57    7.1
# 4               77.14      8.57    1552.0            NaN     NaN    5.7
# ...               ...       ...       ...            ...     ...    ...
# 356022           0.00      0.00       0.0           0.00    0.00    0.0
# 356023            NaN       NaN       NaN            NaN     NaN    NaN
# 356024            NaN       NaN       NaN            NaN     NaN    NaN
# 356025            NaN       NaN       NaN            NaN     NaN    NaN
# 356026           0.00      0.00    2092.0            NaN    0.00    NaN
#
#            salt
# 0           NaN
# 1       0.00000
# 2       0.63500
# 3       1.22428
# 4           NaN
# ...         ...
# 356022  0.00000
# 356023      NaN
# 356024      NaN
# 356025      NaN
# 356026  0.00000
#
# [356027 rows x 9 columns]

# %% [markdown]
# ## Sanitize dataset
#
# It seems like some rows are not following the rule of values per 100g of product, since some foods have values for either protein, fat or carbs above 100.
# For this reason, those rules are pruned from the dataset.
#
# Dataset is then sorted aphabetically by food name.

# %%
df_without_nulls = df_projected.dropna(how='any',axis=0)

# %%
df_without_nulls
# Out:
#                                              product name    fat  \
# 1                          Banana Chips Sweetened (Whole)  28.57
# 2                                                 Peanuts  17.86
# 3                                  Organic Salted Nut Mix  57.14
# 7                                          Organic Muesli  18.75
# 12                                          Zen Party Mix  36.67
# ...                                                   ...    ...
# 355981  Biscuits aux céréales, aux pépites de chocolat...  22.00
# 355985                                    Natural Cassava   0.00
# 356005                Tartines craquantes bio au sarrasin   2.80
# 356017                                 Thé vert Earl grey   0.20
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...   0.00
#
#         carbohydrates  proteins  calories  saturated fat  sugars  fiber  \
# 1               64.29      3.57    2243.0          28.57   14.29    3.6
# 2               60.71     17.86    1941.0           0.00   17.86    7.1
# 3               17.86     17.86    2540.0           5.36    3.57    7.1
# 7               57.81     14.06    1833.0           4.69   15.62    9.4
# 12              36.67     16.67    2230.0           5.00    3.33    6.7
# ...               ...       ...       ...            ...     ...    ...
# 355981          60.00      8.00    2008.0           9.00   27.00    5.0
# 355985          87.06      1.18    1477.0           0.00    2.35    4.7
# 356005          74.80     13.00    1643.0           0.60    2.60    5.9
# 356017           0.50      0.50      21.0           0.20    0.50    0.2
# 356022           0.00      0.00       0.0           0.00    0.00    0.0
#
#            salt
# 1       0.00000
# 2       0.63500
# 3       1.22428
# 7       0.13970
# 12      1.60782
# ...         ...
# 355981  0.28000
# 355985  0.03048
# 356005  0.68000
# 356017  0.02540
# 356022  0.00000
#
# [195851 rows x 9 columns]

# %%
df_sanitized = df_without_nulls[(df_without_nulls["proteins"] < 100) | (df_without_nulls["carbohydrates"] < 100) | (df_without_nulls["fat"] < 100)]
df_sanitized = df_sanitized.drop(df_sanitized[(df_sanitized['proteins'] == 0.0) & (df_sanitized['carbohydrates'] == 0.0) & (df_sanitized['fat'] == 0.0)].index)

# %% [markdown]
# ## Convert kJ to calories

# %%
df_sanitized['calories'] = df_sanitized['calories'].apply(lambda energy: round(float(energy) * 0.239006, 2))

# %% [markdown]
# ## Remove duplicates

# %%
df_no_duplicates = df_sanitized.drop_duplicates('product name')

# %% [markdown]
# ## Sort by name and save final dataset

# %%
final_dataset = df_no_duplicates.sort_values('product name')

# %%
final_dataset.to_csv("openfood_sanitized_dataset.csv", index=False)
