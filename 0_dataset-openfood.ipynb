# %% [markdown]
# # Dataset notebook
#
# Import all the different chunks of the dataset, put into a single file and remove unneeded columns (first two)

# %%
import pandas as pd

# %%
df = pd.read_csv('openfood_dataset.tsv', sep='\t', low_memory=False)

# %%
df.columns.values
# Out:
# array(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity', 'packaging', 'packaging_tags',
#        'brands', 'brands_tags', 'categories', 'categories_tags',
#        'categories_en', 'origins', 'origins_tags', 'manufacturing_places',
#        'manufacturing_places_tags', 'labels', 'labels_tags', 'labels_en',
#        'emb_codes', 'emb_codes_tags', 'first_packaging_code_geo',
#        'cities', 'cities_tags', 'purchase_places', 'stores', 'countries',
#        'countries_tags', 'countries_en', 'ingredients_text', 'allergens',
#        'allergens_en', 'traces', 'traces_tags', 'traces_en',
#        'serving_size', 'no_nutriments', 'additives_n', 'additives',
#        'additives_tags', 'additives_en', 'ingredients_from_palm_oil_n',
#        'ingredients_from_palm_oil', 'ingredients_from_palm_oil_tags',
#        'ingredients_that_may_be_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil',
#        'ingredients_that_may_be_from_palm_oil_tags', 'nutrition_grade_uk',
#        'nutrition_grade_fr', 'pnns_groups_1', 'pnns_groups_2', 'states',
#        'states_tags', 'states_en', 'main_category', 'main_category_en',
#        'image_url', 'image_small_url', 'energy_100g',
#        'energy-from-fat_100g', 'fat_100g', 'saturated-fat_100g',
#        '-butyric-acid_100g', '-caproic-acid_100g', '-caprylic-acid_100g',
#        '-capric-acid_100g', '-lauric-acid_100g', '-myristic-acid_100g',
#        '-palmitic-acid_100g', '-stearic-acid_100g',
#        '-arachidic-acid_100g', '-behenic-acid_100g',
#        '-lignoceric-acid_100g', '-cerotic-acid_100g',
#        '-montanic-acid_100g', '-melissic-acid_100g',
#        'monounsaturated-fat_100g', 'polyunsaturated-fat_100g',
#        'omega-3-fat_100g', '-alpha-linolenic-acid_100g',
#        '-eicosapentaenoic-acid_100g', '-docosahexaenoic-acid_100g',
#        'omega-6-fat_100g', '-linoleic-acid_100g',
#        '-arachidonic-acid_100g', '-gamma-linolenic-acid_100g',
#        '-dihomo-gamma-linolenic-acid_100g', 'omega-9-fat_100g',
#        '-oleic-acid_100g', '-elaidic-acid_100g', '-gondoic-acid_100g',
#        '-mead-acid_100g', '-erucic-acid_100g', '-nervonic-acid_100g',
#        'trans-fat_100g', 'cholesterol_100g', 'carbohydrates_100g',
#        'sugars_100g', '-sucrose_100g', '-glucose_100g', '-fructose_100g',
#        '-lactose_100g', '-maltose_100g', '-maltodextrins_100g',
#        'starch_100g', 'polyols_100g', 'fiber_100g', 'proteins_100g',
#        'casein_100g', 'serum-proteins_100g', 'nucleotides_100g',
#        'salt_100g', 'sodium_100g', 'alcohol_100g', 'vitamin-a_100g',
#        'beta-carotene_100g', 'vitamin-d_100g', 'vitamin-e_100g',
#        'vitamin-k_100g', 'vitamin-c_100g', 'vitamin-b1_100g',
#        'vitamin-b2_100g', 'vitamin-pp_100g', 'vitamin-b6_100g',
#        'vitamin-b9_100g', 'folates_100g', 'vitamin-b12_100g',
#        'biotin_100g', 'pantothenic-acid_100g', 'silica_100g',
#        'bicarbonate_100g', 'potassium_100g', 'chloride_100g',
#        'calcium_100g', 'phosphorus_100g', 'iron_100g', 'magnesium_100g',
#        'zinc_100g', 'copper_100g', 'manganese_100g', 'fluoride_100g',
#        'selenium_100g', 'chromium_100g', 'molybdenum_100g', 'iodine_100g',
#        'caffeine_100g', 'taurine_100g', 'ph_100g',
#        'fruits-vegetables-nuts_100g',
#        'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g',
#        'chlorophyl_100g', 'carbon-footprint_100g',
#        'nutrition-score-fr_100g', 'nutrition-score-uk_100g',
#        'glycemic-index_100g', 'water-hardness_100g'], dtype=object)

# %% [markdown]
# ## Extract just the column needed
#
# - product_name
# - fat_100g
# - carbohydrates_100g
# - proteins_100g
# - energy_100g (kJ)
# - saturated_fat_100g
# - sugars_100g
# - fiber_100g
# - salt_100g

# %%
COLUMNS = ["product_name", "fat_100g", "carbohydrates_100g", "proteins_100g", "energy_100g", "saturated-fat_100g", "sugars_100g", "fiber_100g", "salt_100g"]

# %%
df_projected = df[COLUMNS]

# %%
df_projected
# Out:
#                                              product_name  fat_100g  \
# 0                                      Farine de blé noir       NaN
# 1                          Banana Chips Sweetened (Whole)     28.57
# 2                                                 Peanuts     17.86
# 3                                  Organic Salted Nut Mix     57.14
# 4                                         Organic Polenta      1.43
# ...                                                   ...       ...
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...      0.00
# 356023                                            乐吧泡菜味薯片       NaN
# 356024                                      Biscottes bio       NaN
# 356025                           Tomates aux Vermicelles        NaN
# 356026                    Sugar Free Drink Mix, Peach Tea      0.00
#
#         carbohydrates_100g  proteins_100g  energy_100g  saturated-fat_100g  \
# 0                      NaN            NaN          NaN                 NaN
# 1                    64.29           3.57       2243.0               28.57
# 2                    60.71          17.86       1941.0                0.00
# 3                    17.86          17.86       2540.0                5.36
# 4                    77.14           8.57       1552.0                 NaN
# ...                    ...            ...          ...                 ...
# 356022                0.00           0.00          0.0                0.00
# 356023                 NaN            NaN          NaN                 NaN
# 356024                 NaN            NaN          NaN                 NaN
# 356025                 NaN            NaN          NaN                 NaN
# 356026                0.00           0.00       2092.0                 NaN
#
#         sugars_100g  fiber_100g  salt_100g
# 0               NaN         NaN        NaN
# 1             14.29         3.6    0.00000
# 2             17.86         7.1    0.63500
# 3              3.57         7.1    1.22428
# 4               NaN         5.7        NaN
# ...             ...         ...        ...
# 356022         0.00         0.0    0.00000
# 356023          NaN         NaN        NaN
# 356024          NaN         NaN        NaN
# 356025          NaN         NaN        NaN
# 356026         0.00         NaN    0.00000
#
# [356027 rows x 9 columns]

# %% [markdown]
# ## Sanitize dataset
#
# It seems like some rows are not following the rule of values per 100g of product, since some foods have values for either protein, fat or carbs above 100.
# For this reason, those rules are pruned from the dataset.
#
# Dataset is then sorted aphabetically by food name.

# %%
df_without_nulls = df_projected.dropna(how='any',axis=0)

# %%
df_without_nulls
# Out:
#                                              product_name  fat_100g  \
# 1                          Banana Chips Sweetened (Whole)     28.57
# 2                                                 Peanuts     17.86
# 3                                  Organic Salted Nut Mix     57.14
# 7                                          Organic Muesli     18.75
# 12                                          Zen Party Mix     36.67
# ...                                                   ...       ...
# 355981  Biscuits aux céréales, aux pépites de chocolat...     22.00
# 355985                                    Natural Cassava      0.00
# 356005                Tartines craquantes bio au sarrasin      2.80
# 356017                                 Thé vert Earl grey      0.20
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...      0.00
#
#         carbohydrates_100g  proteins_100g  energy_100g  saturated-fat_100g  \
# 1                    64.29           3.57       2243.0               28.57
# 2                    60.71          17.86       1941.0                0.00
# 3                    17.86          17.86       2540.0                5.36
# 7                    57.81          14.06       1833.0                4.69
# 12                   36.67          16.67       2230.0                5.00
# ...                    ...            ...          ...                 ...
# 355981               60.00           8.00       2008.0                9.00
# 355985               87.06           1.18       1477.0                0.00
# 356005               74.80          13.00       1643.0                0.60
# 356017                0.50           0.50         21.0                0.20
# 356022                0.00           0.00          0.0                0.00
#
#         sugars_100g  fiber_100g  salt_100g
# 1             14.29         3.6    0.00000
# 2             17.86         7.1    0.63500
# 3              3.57         7.1    1.22428
# 7             15.62         9.4    0.13970
# 12             3.33         6.7    1.60782
# ...             ...         ...        ...
# 355981        27.00         5.0    0.28000
# 355985         2.35         4.7    0.03048
# 356005         2.60         5.9    0.68000
# 356017         0.50         0.2    0.02540
# 356022         0.00         0.0    0.00000
#
# [195851 rows x 9 columns]

# %%
df_sanitized = df_without_nulls[(df_without_nulls["proteins_100g"] < 100) | (df_without_nulls["carbohydrates_100g"] < 100) | (df_without_nulls["fat_100g"] < 100)]
df_sanitized = df_sanitized.drop(df_sanitized[(df_sanitized['proteins_100g'] == 0.0) & (df_sanitized['carbohydrates_100g'] == 0.0) & (df_sanitized['fat_100g'] == 0.0)].index)

# %%
df_sanitized
# Out:
#                                              product_name  fat_100g  \
# 1                          Banana Chips Sweetened (Whole)     28.57
# 2                                                 Peanuts     17.86
# 3                                  Organic Salted Nut Mix     57.14
# 7                                          Organic Muesli     18.75
# 12                                          Zen Party Mix     36.67
# ...                                                   ...       ...
# 355979                                         Fairy tail     12.00
# 355981  Biscuits aux céréales, aux pépites de chocolat...     22.00
# 355985                                    Natural Cassava      0.00
# 356005                Tartines craquantes bio au sarrasin      2.80
# 356017                                 Thé vert Earl grey      0.20
#
#         carbohydrates_100g  proteins_100g  energy_100g  saturated-fat_100g  \
# 1                    64.29           3.57       2243.0               28.57
# 2                    60.71          17.86       1941.0                0.00
# 3                    17.86          17.86       2540.0                5.36
# 7                    57.81          14.06       1833.0                4.69
# 12                   36.67          16.67       2230.0                5.00
# ...                    ...            ...          ...                 ...
# 355979               12.00          12.00         50.0               12.00
# 355981               60.00           8.00       2008.0                9.00
# 355985               87.06           1.18       1477.0                0.00
# 356005               74.80          13.00       1643.0                0.60
# 356017                0.50           0.50         21.0                0.20
#
#         sugars_100g  fiber_100g  salt_100g
# 1             14.29         3.6    0.00000
# 2             17.86         7.1    0.63500
# 3              3.57         7.1    1.22428
# 7             15.62         9.4    0.13970
# 12             3.33         6.7    1.60782
# ...             ...         ...        ...
# 355979        12.00        12.0   12.00000
# 355981        27.00         5.0    0.28000
# 355985         2.35         4.7    0.03048
# 356005         2.60         5.9    0.68000
# 356017         0.50         0.2    0.02540
#
# [193903 rows x 9 columns]

# %%
final_dataset = df_sanitized.sort_values('product_name')
final_dataset
# Out:
#                             product_name  fat_100g  carbohydrates_100g  \
# 331606                 18 marrons glacés       0.8               76.00
# 219939   6 carrés fourrés, saveur amande      14.3               59.10
# 259660             8 Beignet de crevette      10.8               28.70
# 354064                       Beef Madras       7.8                5.40
# 287758                Beeren schokoliert      36.5               45.60
# ...                                  ...       ...                 ...
# 293401                          超大紅寶石葡萄乾       0.0               77.50
# 293825                     道地百果園柑桔檸檬果汁飲品       0.0                6.20
# 313397                            頂好牌花生醬      48.7               25.30
# 350849                              초고추장       0.0               47.37
# 350869                             칠성사이다       0.0               10.80
#
#         proteins_100g  energy_100g  saturated-fat_100g  sugars_100g  \
# 331606           0.80       1378.0                 0.1        56.00
# 219939           5.50       1636.0                 6.2        34.30
# 259660           5.10        977.0                 0.8         9.90
# 354064          12.40        601.0                 4.5         4.00
# 287758           8.30       2296.0                22.9        45.30
# ...               ...          ...                 ...          ...
# 293401           2.50       1339.0                 0.0        72.50
# 293825           0.00        439.0                 0.0         6.10
# 313397          22.50       2431.0                11.5        10.60
# 350849           5.26        883.0                 0.0        21.05
# 350869           0.00        184.0                 0.0         8.40
#
#         fiber_100g  salt_100g
# 331606         4.8   0.050038
# 219939         2.6   0.530000
# 259660         0.4   1.750000
# 354064         1.2   0.838200
# 287758         3.6   0.300000
# ...            ...        ...
# 293401         5.0   0.063500
# 293825         0.0   0.071000
# 313397        12.2   0.988060
# 350849         5.3   4.813300
# 350869         0.0   0.040000
#
# [193903 rows x 9 columns]

# %% [markdown]
# ## Save final dataset

# %%
final_dataset.to_csv("projected_food_dataset.csv")
